# %% [markdown]
# <a href="https://colab.research.google.com/github/fbrreis/pandas_Alura/blob/main/Desafios_Alura.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercício 1

# %% [markdown]
# Importe o arquivo alunos.csv e armazene seu conteúdo em um DataFrame Pandas.

# %%
import pandas as pd

url = 'https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/desafios/alunos.csv'
pd.read_csv(url)
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 1         Ana     18    NaN     False
# 2       Cátia     27    2.5     False
# 3       Denis     18    5.0     False
# 4        Beto     21   10.0      True
# 5       Bruna     23    NaN     False
# 6        Dara     21    7.0      True
# 7      Carlos     19    6.0      True
# 8       Alice     35    5.6     False
# 9       Vitor     28    NaN     False
# 10     Daniel     21    NaN     False
# 11       Igor     24    4.5     False
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 14      Paulo     37    NaN     False
# 15     Mylena     29    7.0      True
# 16      Lucas     33    NaN     False
# 17      Nadia     34    8.0      True

# %%
alunos = pd.read_csv(url)
alunos
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 1         Ana     18    NaN     False
# 2       Cátia     27    2.5     False
# 3       Denis     18    5.0     False
# 4        Beto     21   10.0      True
# 5       Bruna     23    NaN     False
# 6        Dara     21    7.0      True
# 7      Carlos     19    6.0      True
# 8       Alice     35    5.6     False
# 9       Vitor     28    NaN     False
# 10     Daniel     21    NaN     False
# 11       Igor     24    4.5     False
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 14      Paulo     37    NaN     False
# 15     Mylena     29    7.0      True
# 16      Lucas     33    NaN     False
# 17      Nadia     34    8.0      True

# %%
alunos.to_csv('Alunos.csv')

# %% [markdown]
# Visualize as primeiras 7 linhas do DataFrame e as 5 últimas.

# %%
alunos.head(7)
# Out:
#     Nome  Idade  Notas  Aprovado
# 0    Ary     20    7.5      True
# 1    Ana     18    NaN     False
# 2  Cátia     27    2.5     False
# 3  Denis     18    5.0     False
# 4   Beto     21   10.0      True
# 5  Bruna     23    NaN     False
# 6   Dara     21    7.0      True

# %%
alunos.tail(5)
# Out:
#       Nome  Idade  Notas  Aprovado
# 13   Mirla     25    9.0      True
# 14   Paulo     37    NaN     False
# 15  Mylena     29    7.0      True
# 16   Lucas     33    NaN     False
# 17   Nadia     34    8.0      True

# %% [markdown]
# Confira a quantidade de linhas e colunas desse DataFrame.

# %%
alunos.shape
# Out:
# (18, 4)

# %% [markdown]
# Explore as colunas do DataFrame e analise os tipos dos dados presentes em cada coluna.

# %%
alunos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Nome      18 non-null     object
#  1   Idade     18 non-null     int64
#  2   Notas     12 non-null     float64
#  3   Aprovado  18 non-null     bool
# dtypes: bool(1), float64(1), int64(1), object(1)
# memory usage: 578.0+ bytes

# %% [markdown]
# Calcule algumas estatísticas descritivas básicas dos dados do DataFrame (média, desvio padrão, etc).

# %%
alunos.describe()
# Out:
#            Idade      Notas
# count  18.000000  12.000000
# mean   25.500000   6.800000
# std     6.070662   2.204953
# min    18.000000   2.500000
# 25%    21.000000   5.450000
# 50%    24.500000   7.000000
# 75%    28.750000   8.250000
# max    37.000000  10.000000

# %%
alunos[['Idade', 'Notas']].mean()
# Out:
# Idade    25.5
# Notas     6.8
# dtype: float64

# %%
alunos[['Idade', 'Notas']].std()
# Out:
# Idade    6.070662
# Notas    2.204953
# dtype: float64

# %% [markdown]
# Criando gráficos

# %%
alunos['Idade'].plot(kind='barh', figsize=(14,10), color='blue')
#ou alunos.Idade.plot(kind='barh', figsize=(14,10), color='blue')
# Out:
# <Axes: >

# %% [markdown]
# # Exercício 2

# %% [markdown]
#  Calcular a média de quartos por apartamento

# %%
pd.read_csv('aluguel.csv')
dados= pd.read_csv('aluguel.csv')
dados
# Out:
#       Tipo;Bairro;Quartos;Vagas;Suites;Area;Valor;Condominio;IPTU
# 0              Quitinete;Copacabana;1;0;0;40;1700;500;60
# 1                  Casa;Jardim Botânico;2;0;1;100;7000;;
# 2      Conjunto Comercial/Sala;Barra da Tijuca;0;4;0;...
# 3                 Apartamento;Centro;1;0;0;15;800;390;20
# 4             Apartamento;Higienópolis;1;0;0;48;800;230;
# ...                                                  ...
# 32955               Quitinete;Centro;0;0;0;27;800;350;25
# 32956       Apartamento;Jacarepaguá;3;1;2;78;1800;800;40
# 32957  Apartamento;São Francisco Xavier;2;1;0;48;1400...
# 32958              Apartamento;Leblon;2;0;0;70;3000;760;
# 32959  Conjunto Comercial/Sala;Centro;0;0;0;250;6500;...
#
# [32960 rows x 1 columns]

# %%
dados= pd.read_csv('aluguel.csv', sep = ';')
dados
# Out:
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 0                    Quitinete            Copacabana        1      0       0
# 1                         Casa       Jardim Botânico        2      0       1
# 2      Conjunto Comercial/Sala       Barra da Tijuca        0      4       0
# 3                  Apartamento                Centro        1      0       0
# 4                  Apartamento          Higienópolis        1      0       0
# ...                        ...                   ...      ...    ...     ...
# 32955                Quitinete                Centro        0      0       0
# 32956              Apartamento           Jacarepaguá        3      1       2
# 32957              Apartamento  São Francisco Xavier        2      1       0
# 32958              Apartamento                Leblon        2      0       0
# 32959  Conjunto Comercial/Sala                Centro        0      0       0
#
#        Area   Valor  Condominio    IPTU
# ...

# %%
dados['Tipo'].unique()
# Out:
# array(['Quitinete', 'Casa', 'Conjunto Comercial/Sala', 'Apartamento',
#        'Casa de Condomínio', 'Prédio Inteiro', 'Flat', 'Loja/Salão',
#        'Galpão/Depósito/Armazém', 'Casa Comercial', 'Casa de Vila',
#        'Terreno Padrão', 'Box/Garagem', 'Loft',
#        'Loja Shopping/ Ct Comercial', 'Chácara', 'Loteamento/Condomínio',
#        'Sítio', 'Pousada/Chalé', 'Studio', 'Hotel', 'Indústria'],
#       dtype=object)

# %%
dados.query('Tipo == "Apartamento"')
apartamento= dados.query('Tipo == "Apartamento"')
apartamento.head()
# Out:
#            Tipo        Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 3   Apartamento        Centro        1      0       0    15   800.0
# 4   Apartamento  Higienópolis        1      0       0    48   800.0
# 5   Apartamento  Vista Alegre        3      1       0    70  1200.0
# 6   Apartamento      Cachambi        2      0       0    50  1300.0
# 10  Apartamento        Centro        1      0       0    36  1200.0
#
#     Condominio  IPTU
# 3        390.0  20.0
# 4        230.0   NaN
# 5          NaN   NaN
# 6        301.0  17.0
# 10         NaN   NaN

# %% [markdown]
#  Calcular a média de quartos por apartamento

# %%
apartamento.Quartos.mean()
# Out:
# 2.481568707761622

# %% [markdown]
# Conferir quantos bairros únicos existem na nossa base de dados

# %%
dados.Bairro.unique()
# Out:
# array(['Copacabana', 'Jardim Botânico', 'Barra da Tijuca', 'Centro',
#        'Higienópolis', 'Vista Alegre', 'Cachambi', 'Ramos', 'Grajaú',
#        'Lins de Vasconcelos', 'Botafogo', 'Taquara',
#        'Freguesia (Jacarepaguá)', 'Tijuca', 'Olaria', 'Leblon',
#        'São Cristóvão', 'Ipanema', 'Campo Grande',
#        'Recreio dos Bandeirantes', 'Jardim Oceânico', 'Humaitá',
#        'Península', 'Méier', 'Vargem Pequena', 'Maracanã', 'Jacarepaguá',
#        'Vargem Grande', 'São Conrado', 'Maria da Graça', 'Vila Valqueire',
#        'Gávea', 'Cosme Velho', 'Bonsucesso', 'Todos os Santos',
#        'Laranjeiras', 'Itanhangá', 'Flamengo', 'Praça Seca', 'Piedade',
#        'Lagoa', 'Santo Cristo', 'Largo do Machado', 'Catete',
#        'Jardim Carioca', 'Benfica', 'Glória', 'Vila Isabel',
#        'Quintino Bocaiúva', 'São Francisco Xavier', 'Rocha Miranda',
#        'Engenho Novo', 'Engenho de Dentro', 'Cidade Nova', 'Pilares',
# ...

# %% [markdown]
# Analisar quais bairros possuem a média de valor de aluguel mais elevadas

# %%
dados.groupby('Bairro')['Valor'].mean().sort_values(ascending=False)
# Out:
# Bairro
# Jacarepaguá         314143.489637
# Irajá               154610.470588
# Caju                120264.782609
# Vasco da Gama       120000.000000
# Cidade Nova          88166.692308
#                         ...
# Inhoaíba               738.888889
# Turiaçu                733.333333
# Magalhães Bastos       726.666667
# Santíssimo             709.090909
# Senador Camará         635.000000
# Name: Valor, Length: 162, dtype: float64

# %%
dados.groupby('Bairro')['Valor'].mean().sort_values(ascending=False)
Bairros=dados.groupby('Bairro')['Valor'].mean().sort_values(ascending=False)
Bairros.head()
# Out:
# Bairro
# Jacarepaguá      314143.489637
# Irajá            154610.470588
# Caju             120264.782609
# Vasco da Gama    120000.000000
# Cidade Nova       88166.692308
# Name: Valor, dtype: float64

# %%
Mais_caros=Bairros.head()
Mais_caros
# Out:
# Bairro
# Jacarepaguá      314143.489637
# Irajá            154610.470588
# Caju             120264.782609
# Vasco da Gama    120000.000000
# Cidade Nova       88166.692308
# Name: Valor, dtype: float64

# %% [markdown]
# Criar um gráfico de barras horizontais que apresente os 5 bairros com as médias de valores de aluguel mais elevadas.

# %%
Mais_caros.plot(kind='barh', figsize=(14, 10), color='Blue')
# Out:
# <Axes: ylabel='Bairro'>

# %% [markdown]
# # Exercício 3

# %% [markdown]
# Verifique se a base de dados possui dados nulos e, caso tenha, realize o tratamento desses dados nulos da forma que achar mais coerente com a situação.

# %%
alunos.isnull().sum()
# Out:
# Nome        0
# Idade       0
# Notas       6
# Aprovado    0
# dtype: int64

# %%
alunos.fillna(0, inplace=True)

# %%
alunos.isnull().sum()
# Out:
# Nome        0
# Idade       0
# Notas       0
# Aprovado    0
# dtype: int64

# %% [markdown]
# Os alunos "Alice" e "Carlos", não fazem mais parte da turma. Sendo assim, remova-os da base de dados.

# %%
alunos_a_remover = alunos.query('Nome == "Alice" | Nome == "Carlos"').index
alunos.drop(alunos_a_remover, axis=0, inplace=True)
alunos
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 1         Ana     18    0.0     False
# 2       Cátia     27    2.5     False
# 3       Denis     18    5.0     False
# 4        Beto     21   10.0      True
# 5       Bruna     23    0.0     False
# 6        Dara     21    7.0      True
# 9       Vitor     28    0.0     False
# 10     Daniel     21    0.0     False
# 11       Igor     24    4.5     False
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 14      Paulo     37    0.0     False
# 15     Mylena     29    7.0      True
# 16      Lucas     33    0.0     False
# 17      Nadia     34    8.0      True

# %% [markdown]
# Aplique um filtro que selecione apenas os alunos que foram aprovados.

# %%
Aprovados=alunos['Aprovado']==True
alunos[Aprovados]
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 4        Beto     21   10.0      True
# 6        Dara     21    7.0      True
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 15     Mylena     29    7.0      True
# 17      Nadia     34    8.0      True

# %% [markdown]
# Salve o DataFrame que possui apenas os alunos aprovados em um arquivo csv chamado "alunos_aprovados.csv".

# %%
alunos[Aprovados].to_csv('alunos_aprovados.csv')
pd.read_csv('alunos_aprovados.csv')
# Out:
#    Unnamed: 0       Nome  Idade  Notas  Aprovado
# 0           0        Ary     20    7.5      True
# 1           4       Beto     21   10.0      True
# 2           6       Dara     21    7.0      True
# 3          12  Sthefanie     26    9.5      True
# 4          13      Mirla     25    9.0      True
# 5          15     Mylena     29    7.0      True
# 6          17      Nadia     34    8.0      True

# %%
alunos[Aprovados].to_csv('alunos_aprovados.csv', index=False)
pd.read_csv('alunos_aprovados.csv')
# Out:
#         Nome  Idade  Notas  Aprovado
# 0        Ary     20    7.5      True
# 1       Beto     21   10.0      True
# 2       Dara     21    7.0      True
# 3  Sthefanie     26    9.5      True
# 4      Mirla     25    9.0      True
# 5     Mylena     29    7.0      True
# 6      Nadia     34    8.0      True

# %% [markdown]
# Ao conferir as notas dos alunos aprovados, notamos que algumas notas estavam incorretas. As alunas que tiraram nota 7.0, na verdade, tinham um ponto extra que não foi contabilizado. Sendo assim, substitua as notas 7.0 da base de dados por 8.0.

# %%
alunos[Aprovados] = alunos[Aprovados].replace(7.0, 8.0)
alunos[Aprovados]
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 4        Beto     21   10.0      True
# 6        Dara     21    8.0      True
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 15     Mylena     29    8.0      True
# 17      Nadia     34    8.0      True

# %%
pd.read_csv('aluguel.csv')
# Out:
#       Tipo;Bairro;Quartos;Vagas;Suites;Area;Valor;Condominio;IPTU
# 0              Quitinete;Copacabana;1;0;0;40;1700;500;60
# 1                  Casa;Jardim Botânico;2;0;1;100;7000;;
# 2      Conjunto Comercial/Sala;Barra da Tijuca;0;4;0;...
# 3                 Apartamento;Centro;1;0;0;15;800;390;20
# 4             Apartamento;Higienópolis;1;0;0;48;800;230;
# ...                                                  ...
# 32955               Quitinete;Centro;0;0;0;27;800;350;25
# 32956       Apartamento;Jacarepaguá;3;1;2;78;1800;800;40
# 32957  Apartamento;São Francisco Xavier;2;1;0;48;1400...
# 32958              Apartamento;Leblon;2;0;0;70;3000;760;
# 32959  Conjunto Comercial/Sala;Centro;0;0;0;250;6500;...
#
# [32960 rows x 1 columns]

# %% [markdown]
# # Exercício 4

# %%
pd.read_csv("Alunos.csv")
alunos = pd.read_csv("Alunos.csv")
alunos
# Out:
#     Unnamed: 0       Nome  Idade  Notas  Aprovado
# 0            0        Ary     20    7.5      True
# 1            1        Ana     18    NaN     False
# 2            2      Cátia     27    2.5     False
# 3            3      Denis     18    5.0     False
# 4            4       Beto     21   10.0      True
# 5            5      Bruna     23    NaN     False
# 6            6       Dara     21    7.0      True
# 7            7     Carlos     19    6.0      True
# 8            8      Alice     35    5.6     False
# 9            9      Vitor     28    NaN     False
# 10          10     Daniel     21    NaN     False
# 11          11       Igor     24    4.5     False
# 12          12  Sthefanie     26    9.5      True
# 13          13      Mirla     25    9.0      True
# 14          14      Paulo     37    NaN     False
# 15          15     Mylena     29    7.0      True
# 16          16      Lucas     33    NaN     False
# 17          17      Nadia     34    8.0      True

# %% [markdown]
# Os alunos participaram de uma atividade extracurricular e ganharam pontos extras. Esses pontos extras correspondem a 40% da nota atual de cada um deles. Com base nisso, crie uma coluna chamada "Pontos_extras" que contenha os pontos extras de cada aluno, ou seja, 40% da nota atual deles.

# %%
alunos['Pontos_extras'] = alunos['Notas'] * 0.4
alunos
# Out:
#     Unnamed: 0       Nome  Idade  Notas  Aprovado  Pontos_extras
# 0            0        Ary     20    7.5      True           3.00
# 1            1        Ana     18    NaN     False            NaN
# 2            2      Cátia     27    2.5     False           1.00
# 3            3      Denis     18    5.0     False           2.00
# 4            4       Beto     21   10.0      True           4.00
# 5            5      Bruna     23    NaN     False            NaN
# 6            6       Dara     21    7.0      True           2.80
# 7            7     Carlos     19    6.0      True           2.40
# 8            8      Alice     35    5.6     False           2.24
# 9            9      Vitor     28    NaN     False            NaN
# 10          10     Daniel     21    NaN     False            NaN
# 11          11       Igor     24    4.5     False           1.80
# 12          12  Sthefanie     26    9.5      True           3.80
# ...

# %% [markdown]
# Crie mais uma coluna, chamada "Notas_finais" que possua as notas de cada aluno somada com os pontos extras.

# %%
alunos['Notas_finais'] = alunos['Notas'] + alunos['Pontos_extras']
alunos
# Out:
#     Unnamed: 0       Nome  Idade  Notas  Aprovado  Pontos_extras  Notas_finais
# 0            0        Ary     20    7.5      True           3.00         10.50
# 1            1        Ana     18    NaN     False            NaN           NaN
# 2            2      Cátia     27    2.5     False           1.00          3.50
# 3            3      Denis     18    5.0     False           2.00          7.00
# 4            4       Beto     21   10.0      True           4.00         14.00
# 5            5      Bruna     23    NaN     False            NaN           NaN
# 6            6       Dara     21    7.0      True           2.80          9.80
# 7            7     Carlos     19    6.0      True           2.40          8.40
# 8            8      Alice     35    5.6     False           2.24          7.84
# 9            9      Vitor     28    NaN     False            NaN           NaN
# 10          10     Daniel     21    NaN     False            NaN           NaN
# ...

# %% [markdown]
# Como houve uma pontuação extra, alguns alunos que não tinham sido aprovados antes podem ter sido aprovados agora. Com base nisso, crie uma coluna chamada "Aprovado_final" com os seguintes valores:
# True: caso o aluno esteja aprovado (nota final deve ser maior ou igual a 6);
# False: caso o aluno esteja reprovado (nota final deve ser menor que 6).

# %%
alunos['Aprovado_final'] = alunos['Notas_finais']. apply(lambda x: "True" if x>=6 else "False")
alunos
# Out:
#     Unnamed: 0       Nome  Idade  Notas  Aprovado  Pontos_extras  \
# 0            0        Ary     20    7.5      True           3.00
# 1            1        Ana     18    NaN     False            NaN
# 2            2      Cátia     27    2.5     False           1.00
# 3            3      Denis     18    5.0     False           2.00
# 4            4       Beto     21   10.0      True           4.00
# 5            5      Bruna     23    NaN     False            NaN
# 6            6       Dara     21    7.0      True           2.80
# 7            7     Carlos     19    6.0      True           2.40
# 8            8      Alice     35    5.6     False           2.24
# 9            9      Vitor     28    NaN     False            NaN
# 10          10     Daniel     21    NaN     False            NaN
# 11          11       Igor     24    4.5     False           1.80
# 12          12  Sthefanie     26    9.5      True           3.80
# ...
